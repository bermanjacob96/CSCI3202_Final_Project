# %%
'''
Jacob Berman
CSCI 3202
Cart-Pole Q-Learning
'''
import numpy as np
import gym
import math
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Initial play

# %%
env = gym.make('CartPole-v0')
env.reset()

for _ in range(1000):
    env.render()
    action = env.action_space.sample()
    env.step(action)
# Out:
# /anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ### Q-learning

# %%
finalRewards = []
timeReq  = []
meanScores = []
meanScores200 = []

class Qlearn:
    
    def __init__(self, buckets=(1, 1, 6, 12,), nEpisodes=1000, nWins=195, minAlpha=0.1, minEpsilon=0.1,
                 gamma=1.0, adaDivisor=25, maxEnvSteps=None, quiet=False, monitor=False):
        
        self.buckets = buckets
        self.nEpisodes = nEpisodes
        self.nWins = nWins
        self.minAlpha = minAlpha
        self.minEpsilon = minEpsilon
        
        self.gamma = gamma
        self.adaDivisor = adaDivisor
        self.quiet = quiet
        
        self.env = gym.make('CartPole-v0')
        
        if maxEnvSteps is not None:
            self.env.maxEpisodeSteps = maxEnvSteps
            
        if monitor:
            self.env = gym.wrappers.Monitor(self.env, 'tmp/cartpole-1', force=True)
                
        self.Q = np.zeros(self.buckets + (self.env.action_space.n,)) #Initialize Q-table
        
    
    def discretize(self, obs):
        
        upperBounds = [self.env.observation_space.high[0], 0.5, self.env.observation_space.high[2], math.radians(50)]
        lowerBounds = [self.env.observation_space.low[0], -0.5, self.env.observation_space.low[2], -math.radians(50)]
        
        ratios = [(obs[i] + abs(lowerBounds[i])) / (upperBounds[i] - lowerBounds[i]) for i in range(len(obs))]
        
        newObsv = [int(round((self.buckets[i] - 1) * ratios[i])) for i in range(len(obs))]
        newObsv = [min(self.buckets[i] - 1, max(0, newObsv[i])) for i in range(len(obs))]
        
        return tuple(newObsv)
            
    def chooseAction(self, state, epsilon):
        
        return self.env.action_space.sample() if (np.random.random() <= epsilon) else np.argmax(self.Q[state])
    
    def updateQ(self, stateOld, action, reward, stateNew, alpha):
        
        self.Q[stateOld][action] += alpha * (reward + self.gamma * np.max(self.Q[stateNew]) - self.Q[stateOld][action])
        
    def getEpsilon(self, t):
        
        return max(self.minEpsilon, min(1, 1.0 - math.log10((t + 1) / self.adaDivisor)))
    
    def getAlpha(self, t):
        
        return max(self.minAlpha, min(1.0, 1.0 - math.log10((t + 1) / self.adaDivisor)))
    
    def run(self):
        
        scores = deque(maxlen=100)
        
        for e in range(self.nEpisodes):
            
            currentState = self.discretize(self.env.reset())
            
            alpha = self.getAlpha(e)
            epsilon = self.getEpsilon(e)
            done = False
            i = 0
            
            for time in range(500):
                
                self.env.render()
                action = self.chooseAction(currentState, epsilon)
                obs, reward, done, _ = self.env.step(action)
                newState = self.discretize(obs)
                self.updateQ(currentState, action, reward, newState, alpha)
                currentState = newState
                i += reward
                
                if done:
                    print('Episode:{}/{} finished with reward:{}'.format(e, self.nEpisodes, time))
                    break
                
            scores.append(i)
            finalRewards.append(i)
            
            meanScore = np.mean(scores)
            meanScore200 = np.mean(scores)

            
            if meanScore >= self.nWins and e >= 100:
                if not self.quiet: print('\nRan {} episodes. Solved after {} episodes'.format(e, e - 100))
                return e - 100
            
            if e == 100:
                print('\n[Episode {}] - Mean time over last 100 episodes was {} ticks.'.format(e, meanScore))
                meanScores.append(meanScore)
                #print(meanScores)
            if e == 200:
                print('\n[Episode {}] - Mean time over last 100 episodes was {} ticks.'.format(e, meanScore200))
                meanScores200.append(meanScore200)
                #print(meanScores200)


        if not self.quiet: print('\nDid not solve after {} episodes'.format(e))
        return e
            
if __name__ == "__main__":
    qlearn = Qlearn()
    qlearn.run()
    #for (x) in range(10): //Uncomment to run 10 tests. Commented out becuase it messes with other graphs.
    #    qlearn.run()
# Out:
# Episode:0/1000 finished with reward:13
# Episode:1/1000 finished with reward:12
# Episode:2/1000 finished with reward:21
# Episode:3/1000 finished with reward:16
# Episode:4/1000 finished with reward:26
# Episode:5/1000 finished with reward:36
# Episode:6/1000 finished with reward:14
# Episode:7/1000 finished with reward:12
# Episode:8/1000 finished with reward:11
# Episode:9/1000 finished with reward:21
# Episode:10/1000 finished with reward:19
# Episode:11/1000 finished with reward:11
# Episode:12/1000 finished with reward:17
# Episode:13/1000 finished with reward:29
# Episode:14/1000 finished with reward:15
# Episode:15/1000 finished with reward:19
# Episode:16/1000 finished with reward:13
# Episode:17/1000 finished with reward:8
# Episode:18/1000 finished with reward:16
# Episode:19/1000 finished with reward:26
# Episode:20/1000 finished with reward:42
# Episode:21/1000 finished with reward:26
# Episode:22/1000 finished with reward:15
# Episode:23/1000 finished with reward:18
# Episode:24/1000 finished with reward:15
# Episode:25/1000 finished with reward:25
# Episode:26/1000 finished with reward:10
# Episode:27/1000 finished with reward:33
# Episode:28/1000 finished with reward:10
# Episode:29/1000 finished with reward:21
# Episode:30/1000 finished with reward:33
# Episode:31/1000 finished with reward:19
# Episode:32/1000 finished with reward:21
# Episode:33/1000 finished with reward:9
# Episode:34/1000 finished with reward:11
# Episode:35/1000 finished with reward:15
# Episode:36/1000 finished with reward:11
# Episode:37/1000 finished with reward:10
# Episode:38/1000 finished with reward:13
# Episode:39/1000 finished with reward:118
# Episode:40/1000 finished with reward:12
# Episode:41/1000 finished with reward:17
# Episode:42/1000 finished with reward:33
# Episode:43/1000 finished with reward:36
# Episode:44/1000 finished with reward:13
# Episode:45/1000 finished with reward:32
# Episode:46/1000 finished with reward:9
# Episode:47/1000 finished with reward:15
# Episode:48/1000 finished with reward:14
# Episode:49/1000 finished with reward:46
# Episode:50/1000 finished with reward:26
# Episode:51/1000 finished with reward:8
# Episode:52/1000 finished with reward:25
# Episode:53/1000 finished with reward:23
# Episode:54/1000 finished with reward:37
# Episode:55/1000 finished with reward:19
# Episode:56/1000 finished with reward:48
# Episode:57/1000 finished with reward:36
# Episode:58/1000 finished with reward:29
# Episode:59/1000 finished with reward:22
# Episode:60/1000 finished with reward:18
# Episode:61/1000 finished with reward:22
# Episode:62/1000 finished with reward:61
# Episode:63/1000 finished with reward:28
# Episode:64/1000 finished with reward:18
# Episode:65/1000 finished with reward:19
# Episode:66/1000 finished with reward:19
# Episode:67/1000 finished with reward:27
# Episode:68/1000 finished with reward:29
# Episode:69/1000 finished with reward:20
# Episode:70/1000 finished with reward:23
# Episode:71/1000 finished with reward:43
# Episode:72/1000 finished with reward:55
# Episode:159/1000 finished with reward:199
# Episode:160/1000 finished with reward:199
# Episode:161/1000 finished with reward:199
# Episode:162/1000 finished with reward:199
# Episode:163/1000 finished with reward:199
# Episode:164/1000 finished with reward:199
# Episode:165/1000 finished with reward:199
# Episode:166/1000 finished with reward:199
# Episode:167/1000 finished with reward:199
# Episode:168/1000 finished with reward:199
# Episode:169/1000 finished with reward:199
# Episode:170/1000 finished with reward:199
# Episode:171/1000 finished with reward:199
# Episode:172/1000 finished with reward:199
# Episode:173/1000 finished with reward:199
# Episode:174/1000 finished with reward:199
# Episode:175/1000 finished with reward:199
# Episode:176/1000 finished with reward:199
# Episode:177/1000 finished with reward:199
# Episode:178/1000 finished with reward:199
# Episode:179/1000 finished with reward:199
# Episode:180/1000 finished with reward:199
# Episode:181/1000 finished with reward:199
# Episode:182/1000 finished with reward:199
# Episode:183/1000 finished with reward:199
# Episode:184/1000 finished with reward:199
# Episode:185/1000 finished with reward:199
# Episode:186/1000 finished with reward:199
# Episode:187/1000 finished with reward:199
# Episode:188/1000 finished with reward:199
# Episode:189/1000 finished with reward:199
# Episode:190/1000 finished with reward:199
# Episode:191/1000 finished with reward:199
# Episode:192/1000 finished with reward:199
# Episode:193/1000 finished with reward:199
# Episode:194/1000 finished with reward:199
# Episode:195/1000 finished with reward:199
# Episode:196/1000 finished with reward:199
# Episode:197/1000 finished with reward:199
# Episode:198/1000 finished with reward:199
# Episode:199/1000 finished with reward:199
# Episode:200/1000 finished with reward:199
#
# [Episode 200] - Mean time over last 100 episodes was 161.64 ticks.
# Episode:201/1000 finished with reward:199
# Episode:202/1000 finished with reward:199
# Episode:203/1000 finished with reward:199
# Episode:204/1000 finished with reward:199
# Episode:205/1000 finished with reward:199
# Episode:206/1000 finished with reward:199
# Episode:207/1000 finished with reward:199
# Episode:208/1000 finished with reward:199
# Episode:209/1000 finished with reward:199
# Episode:210/1000 finished with reward:199
# Episode:211/1000 finished with reward:199
# Episode:212/1000 finished with reward:199
# Episode:213/1000 finished with reward:199
# Episode:214/1000 finished with reward:199
# Episode:215/1000 finished with reward:199
# Episode:216/1000 finished with reward:199
# Episode:217/1000 finished with reward:199
# Episode:218/1000 finished with reward:199
# Episode:219/1000 finished with reward:199
# Episode:220/1000 finished with reward:199
# Episode:221/1000 finished with reward:199
# Episode:222/1000 finished with reward:199
# Episode:223/1000 finished with reward:199
# Episode:224/1000 finished with reward:199
# Episode:225/1000 finished with reward:199
# Episode:226/1000 finished with reward:199
# Episode:227/1000 finished with reward:199
# Episode:228/1000 finished with reward:199
# Episode:229/1000 finished with reward:199
# Episode:230/1000 finished with reward:199
#
# Ran 230 episodes. Solved after 130 episodes

# %%
plt.figure(figsize=(10, 4))
plt.plot(finalRewards)
plt.title('Q-Learning Performance')
plt.xlabel('Episode')
plt.ylabel('Rewards')

plt.figure(figsize=(10, 4))
plt.plot(meanScores)
plt.title('Mean scores for 0-100')
plt.xlabel('Episode')
plt.ylabel('Rewards')

plt.figure(figsize=(10, 4))
plt.plot(meanScores200)
plt.title('Mean scores for 100-200')
plt.xlabel('Episode')
plt.ylabel('Rewards')
# Out:
# Text(0, 0.5, 'Rewards')
